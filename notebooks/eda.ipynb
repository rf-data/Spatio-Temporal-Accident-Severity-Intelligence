# %%
import pandas as pd
from pathlib import Path

folder = "/mnt/chromeos/GoogleDrive/MyDrive/1_Projekte_Datensätze/1_Projekte/4_accidents/data/data_processed"
f_name = "lr_prep_p1_ZeroInf"

f_path = Path(folder) / f"{f_name}.parquet"
df = pd.read_parquet(f_path)

print(df.info())
print("\nHEAD:\n", df.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 992867 entries, 0 to 992866
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   h3_res5       992867 non-null  str
#  1   period        992867 non-null  period[M]
#  2   n_accidents   992867 non-null  float64
#  3   year          216696 non-null  float64
#  4   month         216696 non-null  float64
#  5   lag_1         992866 non-null  float64
#  6   lag_2         992865 non-null  float64
#  7   lag_3         992864 non-null  float64
#  8   lag_12        992855 non-null  float64
#  9   roll_mean_3   992865 non-null  float64
#  10  roll_mean_12  992856 non-null  float64
#  11  roll_sum_3    992865 non-null  float64
#  12  roll_sum_12   992856 non-null  float64
#  13  was_zero      992867 non-null  int64
#  14  zero_streak   992867 non-null  int64
#  15  risk_next     992867 non-null  int64
# dtypes: float64(11), int64(3), period[M](1), str(1)
# ...

# %%
perc = [0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95]


from_period = df["period"].apply(lambda x: (x.dt.year, x.dt.month))
df["year"] = df["year"].fillna(from_period[0])
df["month"] = df["month"].fillna(from_period[0])

print(df.info())
print("\nHEAD:\n", df.head())
# df["year"], df["month"] = df["period"].apply(lambda x: str(x).split("-")) 
# print("DESCRIPTION:\n",df["year"][:5])    #.describe(percentiles=perc))
# # print("\nMAX:\n",df.max())
# # prin

# # for func in [min, max, median, ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 perc = [0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95]
# ----> 4 from_period = df["period"].apply(lambda x: (x.dt.year, x.dt.month))
#       5 df["year"] = df["year"].fillna(from_period[0])
#       6 df["month"] = df["month"].fillna(from_period[0])
#
# File ~/0_Portfolio_Projekte/Road_accidents/.venv/lib/python3.12/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
# ...
